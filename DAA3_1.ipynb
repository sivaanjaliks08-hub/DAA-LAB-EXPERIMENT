# %% [markdown]
# <a href="https://colab.research.google.com/github/sivaanjaliks08-hub/DAA-LAB-EXPERIMENT/blob/main/DAA3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Kruskal's Algorithm for Minimum Spanning Tree (MST)

# -------- Union-Find --------
class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0] * n

    def find(self, x):
        if self.parent[x] != x:
            self.parent[x] = self.find(self.parent[x])   # Path Compression
        return self.parent[x]

    def union(self, x, y):
        rx = self.find(x)
        ry = self.find(y)

        if rx == ry:
            return False

        if self.rank[rx] < self.rank[ry]:
            rx, ry = ry, rx

        self.parent[ry] = rx

        if self.rank[rx] == self.rank[ry]:
            self.rank[rx] += 1

        return True


# -------- Kruskal Algorithm --------
def kruskal(n, edges):
    edges.sort()      # Sort edges by weight

    uf = UnionFind(n)
    mst = []
    cost = 0

    for w, u, v in edges:
        if uf.union(u, v):
            mst.append((u, v, w))
            cost += w

            if len(mst) == n - 1:
                break

    return mst, cost


# -------- Graph Definition --------

cities = ['A', 'B', 'C', 'D', 'E', 'F']

n = len(cities)

edges = [
    (4, 0, 1),   # A-B
    (2, 0, 2),   # A-C
    (5, 1, 2),   # B-C
    (10, 1, 3),  # B-D
    (3, 2, 4),   # C-E
    (7, 3, 4),   # D-E
    (8, 3, 5),   # D-F
    (6, 4, 5)    # E-F
]

# Run Kruskal
mst, total_cost = kruskal(n, edges)

# Display Result
print("=== Kruskal's Minimum Spanning Tree ===\n")

for u, v, w in mst:
    print(f"{cities[u]} -- {cities[v]}   Cost = {w}")

print("\nTotal MST Cost =", total_cost)
# Out:
# === Kruskal's Minimum Spanning Tree ===
#
# A -- C   Cost = 2
# C -- E   Cost = 3
# A -- B   Cost = 4
# E -- F   Cost = 6
# D -- E   Cost = 7
#
# Total MST Cost = 22
